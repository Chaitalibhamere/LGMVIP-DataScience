# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitalibhamere/LGMVIP-DataScience/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LetsGrowMore #Dec2021**
# **Name: Chaitali Bhamere**
#
# **Task2: Image to Pencil Sketch with Python**
#
# **Level: Beginner**
#
# ****
#
# Task description: We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# ## **Importing required libraries**

# %%
#importing libraries
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Reading the image**

# %%
image=cv2.imread("/content/golden-retriever_image.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x635 at 0x7F037B567C90>

# %% [markdown]
# ### **Converting Image to Gray scale image**

# %%
grayscale_image=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=640x635 at 0x7F037A3B4F50>

# %% [markdown]
# ### **Inverting gray scale image**

# %%
inverted_image=cv2.bitwise_not(grayscale_image)                  #bitwise_not func to invert the image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=640x635 at 0x7F037B455190>

# %% [markdown]
# ### **smoothing image**

# %%
img_smoothing=cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)        
#used the guassian blur technique and the default sigma filter to smoothen the image
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=640x635 at 0x7F037A3A6D10>

# %% [markdown]
# ### **Final pencil sketch**

# %%
def pencil_sketch(x, y):
#dividing the grayscale value by the inverse of blurred image value which highlights the boldest edges 
   return cv2.divide(x, 255 - y, scale=256)
pencil_sketch=pencil_sketch(grayscale_image,img_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=640x635 at 0x7F037A37F5D0>

# %% [markdown]
# ### **Viewing both images**

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=640x635 at 0x7F037A2F9650>
# <PIL.Image.Image image mode=L size=640x635 at 0x7F037A2F9F50>
